# %%
## Add classification values to true and fake data then combine them

# %%
import pandas as pd

# %%
fake_data = pd.read_csv('data/fake_clean.csv')

# %%
true_data = pd.read_csv('data/true_clean.csv')

# %%
fake_data
# Out:
#                                                    title
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain  John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E mail Privacy Class ac...
# 23478  Sunnistan  US and Allied  Safe Zone’ Plan to T...
# 23479  How to Blow  700 Million  Al Jazeera America F...
# 23480  10 U S  Navy Sailors Held by Iranian Military ...
#
# [23481 rows x 1 columns]

# %%
fake_data['Classifier'] = 1

# %%
fake_data
# Out:
#                                                    title  Classifier
# 0       Donald Trump Sends Out Embarrassing New Year’...           1
# 1       Drunk Bragging Trump Staffer Started Russian ...           1
# 2       Sheriff David Clarke Becomes An Internet Joke...           1
# 3       Trump Is So Obsessed He Even Has Obama’s Name...           1
# 4       Pope Francis Just Called Out Donald Trump Dur...           1
# ...                                                  ...         ...
# 23476  McPain  John McCain Furious That Iran Treated ...           1
# 23477  JUSTICE? Yahoo Settles E mail Privacy Class ac...           1
# 23478  Sunnistan  US and Allied  Safe Zone’ Plan to T...           1
# 23479  How to Blow  700 Million  Al Jazeera America F...           1
# 23480  10 U S  Navy Sailors Held by Iranian Military ...           1
#
# [23481 rows x 2 columns]

# %%
true_data['Classifier'] = 0

# %%
true_data

# %%
data_append = true_data.append(fake_data)

# %%
data_append.to_csv('data/append_file.csv', index=False)

# %%
new_append = pd.read_csv('data/append_file.csv')

# %%
data_shuffle = new_append.sample(frac=1)

# %%
data_shuffle.to_csv('data/shuffle_file.csv')

# %%
row_count = data_shuffle['title'].count()

# %%
row_count
# Out:
# 44898

# %%
test_set = data_shuffle.tail(math.floor(0.1*row_count))

# %%
test_set
# Out:
#                                                    title  Classifier
# 9235   Senator Tim Kaine an online favorite to run wi...           0
# 22004  Ron Paul Liberty Report  US Saudi Arms Traffic...           1
# 18742  Hoyer, asked on German finmin post, says 'extr...           0
# 13749  New Venezuela oil boss to give military more P...           0
# 20738  Tunisia's new government gets party backing fo...           0
# ...                                                  ...         ...
# 9300   Sanders to offer Puerto Rico debt bill that wo...           0
# 23083  Boiler Room  90   Downtown Brown and The Loss ...           1
# 20524  To flee or stay? Irma's shifting path forces s...           0
# 14346  Zimbabwe's ruling party to launch Mugabe impea...           0
# 15178  Oh Brother! White House Compares Obama To The ...           1
#
# [4489 rows x 2 columns]

# %%
final_set = data_shuffle

# %%
cond = final_set['title'].isin(test_set['title'])
final_set.drop(final_set[cond].index, inplace = True)

# %%
final_set
# Out:
#                                                    title  Classifier
# 831     The Eighth Person In Trump Tower Meeting Is L...           1
# 341     Anti Porn GOP Florida Lawmaker Was Just Caugh...           1
# 7767    White Man Yells  F cking N     s,’ Shoots At ...           1
# 18420  WOW! Soon To Be Former GOP Congressman Jason C...           1
# 20803  Ex-minister accuses former Brazil President Lu...           0
# ...                                                  ...         ...
# 1467    Chris Wallace SCOLDS Fox News Colleagues For ...           1
# 18099  REMEMBER WHEN DONALD TRUMP FOUGHT Palm Beach O...           1
# 3621   Amid opposition, Trump makes low budget reques...           0
# 10151   Thank you, President Trump  Mother of Charlot...           1
# 18854   GODFATHER OF FAKE NEWS  Brian Williams Calls ...           1
#
# [34475 rows x 2 columns]

# %%
44898-4489
# Out:
# 40409
